# %%
path = "X:\Directory\研究生\论文\\1\实验数据"
readData = pd.read_csv(f"{path}\Cifar10 PoisonPatch benign test acc.csv",header=None)   #读取csv数据
# print(readData)
acc_patch = readData.iloc[1:-1,1].tolist()      #获取dataFrame，并将此转换为list
acc_poison = readData.iloc[1:-1,2].tolist()
epochs = readData.iloc[1:-1,3].tolist()     #产生横轴坐标
acc_patch = list(map(float, acc_patch))
acc_poison = list(map(float, acc_poison))

plt.figure(figsize = (7,6),dpi = 70)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(250)
y = MultipleLocator(20)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')      # 添加网格线
plt.title("折线图标题")      # 折线图标题
plt.xlabel("X轴名称")        #X轴名称
plt.ylabel("Y轴名称")        #Y轴名称
plt.xlim(0, 1250)
plt.ylim(0, 100)
plt.plot(epochs, acc_patch)     #绘制折线图
plt.legend(['折线名称'])        # 设置折线名称
# plt.savefig('折线图1.jpg')    # 保存到本地文件夹，当前路径下
plt.show()

# %% [markdown]
# 当Y轴的数字顺序不对时（乱序），是因为Y轴的数值类型不是int型 所以无法排序，都改为int就行
# 当split()分割后的字符串无法转为int时，可能是因为原始数据中首位有[]没有删去

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 2
#       1 filepath = 'D:\\code\\code_xwd\\neurotoxin\\FL_Backdoor_CV\\saved_backdoor_acc_edge_case0_datasetcifar100_save_model_EE3801\\Local_backdoor_cv_cifar100_resnet_snorm0.2_Baseline_Lr0.001_PLr0.003_TLr0.2_AttackNum200_SE1801_AllLayer1.txt'
# ----> 2 with open(filepath,'r') as f:
#       3     line = f.readline().lstrip("[")
#       4     nline = line.lstrip("]")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\code\\code_xwd\\neurotoxin\\FL_Backdoor_CV\\saved_backdoor_acc_edge_case0_datasetcifar100_save_model_EE3801\\Local_backdoor_cv_cifar100_resnet_snorm0.2_Baseline_Lr0.001_PLr0.003_TLr0.2_AttackNum200_SE1801_AllLayer1.txt'

# %%
path = "X:\Directory\研究生\论文\\1\实验数据"
readData = pd.read_csv(f"{path}\Cifar10 PoisonPatch benign test acc.csv",header=None)   #读取csv数据
# print(readData)
acc_patch = readData.iloc[1:-1,1].tolist()      #获取dataFrame，并将此转换为list
acc_poison = readData.iloc[1:-1,2].tolist()
epochs = readData.iloc[1:-1,3].tolist()     #产生横轴坐标
acc_patch = list(map(float, acc_patch))
acc_poison = list(map(float, acc_poison))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(100)
y = MultipleLocator(20)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')      # 添加网格线
plt.title("benign test acc")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("benign test acc")        #Y轴名称
plt.xlim(0, 500)
plt.ylim(0, 100)
plt.plot(epochs, acc_patch, label='patch')     #绘制折线图
plt.plot(epochs, acc_poison, label='poison')
plt.legend(ncol=1, loc=1) 
# plt.savefig('折线图1.jpg')   # 保存到本地文件夹，当前路径下
plt.show()
