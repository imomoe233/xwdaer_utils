# %% [markdown]
# 折线图 模板

# %%
path = "D:/code/code_xwd/xwdaer_utils/org_data"
readData = pd.read_csv(f"{path}/Cifar10 PoisonPatch benign test acc.csv",header=None)   #读取csv数据
# print(readData)
epochs = readData.iloc[1:-1,1].tolist()
acc_patch = readData.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
acc_patch = list(map(float, acc_patch))
acc_poison = readData.iloc[1:-1,3].tolist()
acc_poison = list(map(float, acc_poison))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(250)
y = MultipleLocator(20)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')      # 添加网格线
plt.title("折线图标题")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("Y轴名称")        #Y轴名称
plt.xlim(0, 1250)
plt.ylim(0, 100)
plt.plot(epochs, acc_patch)     #绘制折线图
plt.legend(['折线名称'])        # 设置折线名称
# plt.savefig('折线图1.jpg')    # 保存到本地文件夹，当前路径下
plt.show()

# %% [markdown]
# 当Y轴的数字顺序不对时（乱序），是因为Y轴的数值类型不是int型 所以无法排序，都改为int就行
# 当split()分割后的字符串无法转为int时，可能是因为原始数据中首位有[]没有删去

# %% [markdown]
# 要导入的包 ↓ 用前导入

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np
import pandas as pd
from matplotlib.patches import  ConnectionPatch

# %% [markdown]
# 局部放大图

# %%
axins = ax.inset_axes((0.2, 0.2, 0.4, 0.3))
axins.plot(x, y1, label='patch')     #绘制折线图
axins.plot(x, y2, label='poison')
axins.plot(x, y3, label='noAttack')
# 设置放大区间
zone_left = 600
zone_right = 800

# 坐标轴的扩展比例（根据实际数据调整）
x_ratio = 0  # x轴显示范围的扩展比例
y_ratio = 0.05  # y轴显示范围的扩展比例

# X轴的显示范围
xlim0 = x[zone_left]-(x[zone_right]-x[zone_left])*x_ratio
xlim1 = x[zone_right]+(x[zone_right]-x[zone_left])*x_ratio

# Y轴的显示范围
y = np.hstack((y1[zone_left:zone_right], y2[zone_left:zone_right],
               y3[zone_left:zone_right]))
ylim0 = np.min(y)-(np.max(y)-np.min(y))*y_ratio
ylim1 = np.max(y)+(np.max(y)-np.min(y))*y_ratio

# 调整子坐标系的显示范围
axins.set_xlim(xlim0, xlim1)
axins.set_ylim(ylim0, ylim1)

# 原图中画方框
tx0 = xlim0
tx1 = xlim1
ty0 = ylim0
ty1 = ylim1
sx = [tx0,tx1,tx1,tx0,tx0]
sy = [ty0,ty0,ty1,ty1,ty0]
ax.plot(sx,sy,"black")

# 画两条线
xy = (xlim0,ylim0)
xy2 = (xlim0,ylim1)
con = ConnectionPatch(xyA=xy2,xyB=xy,coordsA="data",coordsB="data",
        axesA=axins,axesB=ax)
axins.add_artist(con)

xy = (xlim1,ylim0)
xy2 = (xlim1,ylim1)
con = ConnectionPatch(xyA=xy2,xyB=xy,coordsA="data",coordsB="data",
        axesA=axins,axesB=ax)
axins.add_artist(con)

# %% [markdown]
# cifar10 PoisonPatch backdoor test acc 后门准确率

# %%
path = "./org_data/"
readData = pd.read_csv(f"{path}\Cifar10 PoisonPatch backdoor test acc.csv",header=None)   #读取csv数据
# print(readData)
epochs = readData.iloc[1:-1,1].tolist() 
acc_patch = readData.iloc[1:-1,2].tolist()
acc_patch = list(map(float, acc_patch))
acc_poison = readData.iloc[1:-1,3].tolist()
acc_poison = list(map(float, acc_poison))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(100)
y = MultipleLocator(20)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')      # 添加网格线
plt.title("backdoor test acc")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("backdoor test acc")        #Y轴名称
plt.xlim(0, 800)
plt.ylim(0, 100)
plt.plot(epochs, acc_patch, label='patch')     #绘制折线图
plt.plot(epochs, acc_poison, label='poison')
plt.legend(ncol=1, loc=1) 
# plt.savefig('折线图1.jpg')   # 保存到本地文件夹，当前路径下
plt.show()

# %% [markdown]
# cifar10 PoisonPatch benign test acc 良性准确率

# %%
path = "./org_data/"
readData = pd.read_csv(f"{path}\Cifar10 PoisonPatch benign test acc.csv",header=None)   #读取csv数据
# print(readData)
epochs = readData.iloc[1:-1,1].tolist()
acc_patch = readData.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
acc_patch = list(map(float, acc_patch))
acc_poison = readData.iloc[1:-1,3].tolist()
acc_poison = list(map(float, acc_poison))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(100)
y = MultipleLocator(20)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')      # 添加网格线
plt.title("benign test acc")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("benign test acc")        #Y轴名称
plt.xlim(0, 800)
plt.ylim(0, 100)
plt.plot(epochs, acc_patch, label='patch')     #绘制折线图
plt.plot(epochs, acc_poison, label='poison')
plt.legend(ncol=1, loc=1) 
# plt.savefig('折线图1.jpg')   # 保存到本地文件夹，当前路径下
plt.show()

# %% [markdown]
# 后门前后的良性样本准确率

# %%
path = "./org_data/"
readData = pd.read_csv(f"{path}\Cifar10 PoisonPatch clean accuracy drop(CAD).csv",header=None)   #读取csv数据
# print(readData)
epochs = readData.iloc[1:-1,1].tolist()
epochs = list(map(int, epochs))
acc_patch = readData.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
acc_patch = list(map(float, acc_patch))
acc_poison = readData.iloc[1:-1,3].tolist()
acc_poison = list(map(float, acc_poison))
acc_noAttack = readData.iloc[1:-1,4].tolist()
acc_noAttack = list(map(float, acc_noAttack))

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

plt.figure(figsize = (9,5),dpi = 100)

x = MultipleLocator(100)
y = MultipleLocator(20)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')            # 添加网格线

plt.title("benign test acc")         # 折线图标题
plt.xlabel("epochs")                 #X轴名称
plt.ylabel("benign test acc")        #Y轴名称
plt.xlim(0, 800)
plt.ylim(0, 100)
plt.plot(epochs, acc_patch, label='patch')     #绘制折线图
plt.plot(epochs, acc_poison, label='poison')
plt.plot(epochs, acc_noAttack, label='noAttack')
plt.legend(ncol=1, loc=0) 
# plt.savefig('折线图1.jpg')   # 保存到本地文件夹，当前路径下


axins = ax.inset_axes((0.5, 0.2, 0.4, 0.3))
axins.plot(epochs, acc_patch, label='patch')     #绘制折线图
axins.plot(epochs, acc_poison, label='poison')
axins.plot(epochs, acc_noAttack, label='noAttack')
# 设置放大区间
zone_left = 750
zone_right = 800

# 坐标轴的扩展比例（根据实际数据调整）
x_ratio = 0  # x轴显示范围的扩展比例
y_ratio = 0.05  # y轴显示范围的扩展比例

# X轴的显示范围
xlim0 = epochs[zone_left]-(epochs[zone_right]-epochs[zone_left])*x_ratio
xlim1 = epochs[zone_right]+(epochs[zone_right]-epochs[zone_left])*x_ratio

# Y轴的显示范围
y = np.hstack((acc_patch[zone_left:zone_right], acc_poison[zone_left:zone_right],
               acc_noAttack[zone_left:zone_right]))
ylim0 = np.min(y)-(np.max(y)-np.min(y))*y_ratio
ylim1 = np.max(y)+(np.max(y)-np.min(y))*y_ratio

# 调整子坐标系的显示范围
axins.set_xlim(xlim0, xlim1)
axins.set_ylim(ylim0, ylim1)

# 原图中画方框
tx0 = xlim0
tx1 = xlim1
ty0 = ylim0
ty1 = ylim1
sx = [tx0,tx1,tx1,tx0,tx0]
sy = [ty0,ty0,ty1,ty1,ty0]
ax.plot(sx,sy,"black")

# 画两条线
xy = (xlim0,ylim0)
xy2 = (xlim0,ylim1)
con = ConnectionPatch(xyA=xy2,xyB=xy,coordsA="data",coordsB="data",
        axesA=axins,axesB=ax)
axins.add_artist(con)

xy = (xlim1,ylim0)
xy2 = (xlim1,ylim1)
con = ConnectionPatch(xyA=xy2,xyB=xy,coordsA="data",coordsB="data",
        axesA=axins,axesB=ax)
axins.add_artist(con)

plt.show()

# %% [markdown]
# 后门前后的良性样本准确率变化比 Clean accuracy drop (CAD)

# %%
path = "./org_data/"
readData = pd.read_csv(f"{path}\Cifar10 PoisonPatch clean accuracy drop(CAD).csv",header=None)   #读取csv数据
# print(readData)
epochs = readData.iloc[1:-1,1].tolist()
epochs = list(map(int, epochs))
acc_patch = readData.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
acc_patch = list(map(float, acc_patch))
acc_poison = readData.iloc[1:-1,3].tolist()
acc_poison = list(map(float, acc_poison))
acc_noAttack = readData.iloc[1:-1,4].tolist()
acc_noAttack = list(map(float, acc_noAttack))

# acc_noAttack_patch = acc_noAttack - acc_patch
acc_noAttack_patch = list(map(lambda x: x[0]-x[1], zip(acc_noAttack, acc_patch)))
# acc_noAttack_poison = acc_noAttack - acc_poison
acc_noAttack_poison = list(map(lambda x: x[0]-x[1], zip(acc_noAttack, acc_poison)))

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

plt.figure(figsize = (9,5),dpi = 100)

x = MultipleLocator(100)
y = MultipleLocator(5)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')            # 添加网格线

plt.title("Clean accuracy drop (CAD)")         # 折线图标题
plt.xlabel("epochs")                 #X轴名称
plt.ylabel("Clean accuracy drop")        #Y轴名称
plt.xlim(0, 800)
plt.ylim(-10, 10)
plt.plot(epochs, acc_noAttack_patch, label='noAttack_patch')     #绘制折线图
plt.plot(epochs, acc_noAttack_poison, label='noAttack_poison')
plt.legend(ncol=1, loc=1) 
plt.show()

# %% [markdown]
# 计算 良性样本 在中毒模型下被分类为 ground-truth 真实标签的平均置信度

# %%
from typing import Text
from yaml import tokens
import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset
from torchvision.datasets import MNIST, EMNIST

from helper import Helper
import random
from utils.text_load import Dictionary
from models.word_model import RNNModel
from models.resnet import ResNet18
from models.lenet import LeNet
from models.edge_case_cnn import Net
from models.resnet9 import ResNet9
from utils.text_load import *
import numpy as np
import copy
from torch.utils.data import Dataset, DataLoader

import os
from torchvision import datasets, transforms
from collections import defaultdict
from torch.utils.data import DataLoader, random_split, TensorDataset
import pickle
from gradcam import GradCAM, GradCAMpp
from gradcam.utils import visualize_cam
import PIL
import matplotlib.pyplot as plt

label_dict = {
    0:'plane',
    1:'car',
    2:'bird',
    3:'cat',
    4:'deer',
    5:'dog',
    6:'frog',
    7:'horse',
    8:'ship',
    9:'truck'
}
 
def main():
    model = ResNet18(10)
    model.cuda()

    params = torch.load("D:\code\code_xwd\Durable-Federated-Learning-Backdoor\SAVE_MODEL\cifar10 poisoned attacknum 450\cifar10_central_saved_model\Backdoor_saved_models_update1_noniid_0.9_cifar10_EC0_EE3801\maskratio0.95\Backdoor_model_cifar10_resnet_maskRatio0.95_Snorm_0.2_checkpoint_model_epoch_2150.pth")
    model.load_state_dict(params)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.2,
                                                    momentum=0.09,
                                                    weight_decay=0.4)
    
    gradcam = GradCAM.from_config(model_type='resnet', arch=model, layer_name='layer4')
    for k in range (0, 1):
        
        # get an image and normalize with mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)
        pil_img = PIL.Image.open(f'D:\code\code_xwd\dataset\patched-cifar-10\pic\{k}.jpg')
        torch_img = transforms.Compose([transforms.Resize((32, 32)), transforms.ToTensor()])(pil_img).cuda()
        normed_img = transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])(torch_img)[None]
        # get a GradCAM saliency map on the class index 10.
        output = model(normed_img)
        print(output.data)
        pred = output.data.max(1)[1]
        print(pred)
        
        probs = torch.nn.functional.softmax(output.cpu(), dim=1).detach().numpy()[0]
        
        print(probs)
        
        
        """
        plt.figure(dpi=50,figsize=(32,32))
        for i in range(0, 10):
            mask, logit = gradcam(normed_img, class_idx=i)
    
            # make heatmap from mask and synthesize saliency map using heatmap and img
            heatmap, cam_result = visualize_cam(mask, torch_img)
        
            
            # plt.subplot(1,2,1)
            
            # plt.imshow(transforms.ToPILImage()(heatmap))
            plt.subplot(1, 10, i+1)
            plt.axis("off")
            plt.imshow(transforms.ToPILImage()(cam_result))
            # plt.title(label_dict[i])
        plt.show()
        """


if __name__ == '__main__':
    main()

# %% [markdown]
# 后门生效所需要的轮数

# %%
path = "D:/code/code_xwd/xwdaer_utils/org_data"
readData = pd.read_csv(f"{path}/Cifar10 PoisonPatch 后门生效轮数.csv",header=None)   #读取csv数据
# print(readData)
epochs = readData.iloc[1:-1,1].tolist()
acc_patch = readData.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
acc_patch = list(map(float, acc_patch))
acc_poison = readData.iloc[1:-1,3].tolist()
acc_poison = list(map(float, acc_poison))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(50)
y = MultipleLocator(20)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')      # 添加网格线
plt.title("backdoor take effect epochs")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("backdoor accuracy")        #Y轴名称
plt.xlim(0, 350)
plt.ylim(0, 100)
plt.plot(epochs, acc_patch)     #绘制折线图
plt.plot(epochs, acc_poison)
plt.legend(['patch', 'poison'], loc=4)        # 设置折线名称
# plt.savefig('折线图1.jpg')    # 保存到本地文件夹，当前路径下
plt.show()

# %% [markdown]
# Poison DP前后的良性样本准确率

# %%
path = "D:/code/code_xwd/xwdaer_utils/org_data"
readData = pd.read_csv(f"{path}/Cifar10 Poison DP前后 benign test acc.csv",header=None)   #读取csv数据
# print(readData)
epochs = readData.iloc[1:-1,1].tolist()
benign_acc_DP = readData.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
benign_acc_DP = list(map(float, benign_acc_DP))
benign_acc_withoutDP = readData.iloc[1:-1,3].tolist()
benign_acc_withoutDP = list(map(float, benign_acc_withoutDP))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(100)
y = MultipleLocator(10)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')      # 添加网格线
plt.title("benign test acc with / without DP in Poison")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("benign test acc")        #Y轴名称
plt.xlim(0, 800)
plt.ylim(0, 100)
plt.plot(epochs, benign_acc_withoutDP)
plt.plot(epochs, benign_acc_DP)
plt.legend(['without DP', 'with DP'], loc=4)        # 设置折线名称

# plt.savefig('折线图1.jpg')    # 保存到本地文件夹，当前路径下
plt.show()

# %% [markdown]
# Poison DP前后的后门准确率

# %%
path1 = "D:/code/code_xwd/xwdaer_utils/org_data"
readData1 = pd.read_csv(f"{path1}/Cifar10 Poison DP前后 Poison test acc.csv",header=None)   #读取csv数据
# print(readData)
epochs = readData1.iloc[1:-1,1].tolist()
poison_acc_DP = readData1.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
poison_acc_DP = list(map(float, poison_acc_DP))
poison_acc_withoutDP = readData1.iloc[1:-1,3].tolist()
poison_acc_withoutDP = list(map(float, poison_acc_withoutDP))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(100)
y = MultipleLocator(10)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)


plt.title("backdoor test acc with / without DP in Poison")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("backdoor test acc")        #Y轴名称
plt.xlim(0, 800)
plt.ylim(0, 100)
plt.plot(epochs, poison_acc_withoutDP)
plt.plot(epochs, poison_acc_DP)
plt.legend(['without DP', 'with DP'], loc=4)
plt.show()

# %% [markdown]
# Patch DP前后良性样本准确率

# %%
path = "D:/code/code_xwd/xwdaer_utils/org_data"
readData = pd.read_csv(f"{path}/Cifar10 Patch DP前后 benign test acc.csv",header=None)   #读取csv数据
# print(readData)
epochs = readData.iloc[1:-1,1].tolist()
benign_acc_DP = readData.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
benign_acc_DP = list(map(float, benign_acc_DP))
benign_acc_withoutDP = readData.iloc[1:-1,3].tolist()
benign_acc_withoutDP = list(map(float, benign_acc_withoutDP))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(100)
y = MultipleLocator(10)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')      # 添加网格线
plt.title("benign test acc with / without DP in Patch")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("benign test acc")        #Y轴名称
plt.xlim(0, 800)
plt.ylim(0, 100)
plt.plot(epochs, benign_acc_withoutDP)
plt.plot(epochs, benign_acc_DP)
plt.legend(['without DP', 'with DP'], loc=4)        # 设置折线名称

# plt.savefig('折线图1.jpg')    # 保存到本地文件夹，当前路径下
plt.show()

# %% [markdown]
# Patch DP前后后门准确率

# %%
path1 = "D:/code/code_xwd/xwdaer_utils/org_data"
readData1 = pd.read_csv(f"{path1}/Cifar10 Patch DP前后 Poison test acc.csv",header=None)   #读取csv数据
# print(readData)
epochs = readData1.iloc[1:-1,1].tolist()
poison_acc_DP = readData1.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
poison_acc_DP = list(map(float, poison_acc_DP))
poison_acc_withoutDP = readData1.iloc[1:-1,3].tolist()
poison_acc_withoutDP = list(map(float, poison_acc_withoutDP))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(100)
y = MultipleLocator(10)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)


plt.title("backdoor test acc with / without DP in Patch")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("backdoor test acc")        #Y轴名称
plt.xlim(0, 800)
plt.ylim(0, 100)
plt.plot(epochs, poison_acc_withoutDP)
plt.plot(epochs, poison_acc_DP)
plt.legend(['without DP', 'with DP'], loc=4)
plt.show()

# %% [markdown]
# Cifar10 Poison neurotoxin前后后门准确率

# %%
path = "D:/code/code_xwd/xwdaer_utils/org_data"
readData = pd.read_csv(f"{path}/Cifar10 Poison neurotoxin+grad_dropout前后 poison test acc.csv",header=None)   #读取csv数据
# print(readData)
epochs = readData.iloc[1:-1,1].tolist()
nothing = readData.iloc[1:-1,2].tolist()      #获取dataFrame，并将此转换为list
nothing = list(map(float, nothing))
grad_dropout = readData.iloc[1:-1,3].tolist()
grad_dropout = list(map(float, grad_dropout))
PartFedAvg = readData.iloc[1:-1,4].tolist()
PartFedAvg = list(map(float, PartFedAvg))

plt.figure(figsize = (9,5),dpi = 100)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 显示汉字
plt.rcParams['axes.unicode_minus'] = False    # 用来正常显示负号

x = MultipleLocator(100)
y = MultipleLocator(10)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y)
#把y轴的主刻度设置为10的倍数
ax.autoscale(enable = False)

# plt.style.use('ggplot')      # 添加网格线
plt.title("poison backdoor test acc with / without grad_dropout or PartFedAvg")      # 折线图标题
plt.xlabel("epochs")        #X轴名称
plt.ylabel("backdoor test acc")        #Y轴名称
plt.xlim(0, 1200)
plt.ylim(0, 100)
plt.plot(epochs, nothing)
plt.plot(epochs, grad_dropout)
plt.plot(epochs, PartFedAvg)
plt.legend(['without grad_dropout & PartFedAvg', 'with grad_dropout', 'with grad_dropout & PartFedAvg'], loc=4)        # 设置折线名称

# plt.savefig('折线图1.jpg')    # 保存到本地文件夹，当前路径下
plt.show()
